# %% [markdown]
# 作業目標<br>
# 讀取存取陣列資料<br>
# 作業重點<br>
# 多陣列存一起需要存成npz，讀取須注意npz中有多個陣列

# %% [markdown]
# 題目:<br>
# 1. 將下兩列array存成npz檔<br>
# array1 = np.array(range(30))<br>
# array2 = np.array([2,3,5])<br>
# 2. 讀取剛剛的npz檔，加入下列array一起存成新的npz檔

# %%
#. 將下兩列array存成npz檔
import numpy as np

array1 = np.array(range(30))
array2 = np.array([2,3,5])

with open('mix_array.npz', 'wb') as f:
    np.savez(f, array_1 = array1, array_2 = array2)

# %%
#2. 讀取剛剛的npz檔，加入下列array一起存成新的npz檔
npzfile = np.load('mix_array.npz')
print(npzfile.files)

npzfile_multi_array = np.load('multi_array.npz')
npzfile_one_array = np.load('one_array.npy')
with open('mix_array_1.npz', 'wb') as f:
    np.savez(f, npzfile, npzfile_multi_array, npzfile_one_array)
npzfile = np.load('mix_array_1.npz')
print(npzfile.files)
# Out:
# ['arr_0', 'arr_1']
# ['arr_0', 'arr_1', 'arr_2']
